# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]>

# %%
df.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
import pandas as pd
music_data = pd.read_csv('music.csv')
X = music_data.drop(columns = ['genre'])
y = music_data['genre']
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
music_data = pd.read_csv('music.csv')
X = music_data.drop(columns = ['genre'])
Y = music_data['genre']

modal = DecisionTreeClassifier()
modal.fit(X,Y)
prediction = modal.predict([ [21,1], [22,0]])
prediction
# Out:
# /Users/utkarshsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
import pandas as pd
music_data = pd.read_csv('music.csv')
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
music_data = pd.read_csv('music.csv')
X = music_data.drop(columns = ['genre'])
y = music_data['genre']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

modal = DecisionTreeClassifier()
modal.fit(X_train,y_train)
prediction = modal.predict(X_test)

score = accuracy_score(y_test, prediction)
score
# Out:
# 1.0

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random 

G=nx.Graph()
city_set = ['Mumbai', 'Chennai', 'Pune', 'Banglore', 'Surat', 'Hyderabad', 'Jammu', 'Kashmir']
for each in city_set:
    G.add_node(each)
    
costs=[]
value=100

while(value<=2000):
    costs.append(value)
    value=value+100

while(G.number_of_edges()<16):
    c1=random.choice(list(G.nodes()))
    c2=random.choice(list(G.nodes()))
    if c1!=c2 and G.has_edge(c1,c2) == 0:
        w=random.choice(costs)
        G.add_edge(c1,c2,weight=w)
        
pos=nx.circular_layout(G)
nx.draw(G,with_labels=True)
plt.show()

# %%
# Out:
# 1   HIToolbox                           0x00007ff818a06726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff818a062b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff8189aa908 SetMenuBarObscured + 408
# 4   HIToolbox                           0x00007ff8189aa4ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 5   HIToolbox                           0x00007ff8189a4996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 6   HIToolbox                           0x00007ff81896cbd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff8189a43e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff8189933ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff8189932b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff811b90f33 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff811b8fdb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  libtk8.6.dylib                      0x000000011021907e TkMacOSXEventsCheckProc + 494
# 13  libtcl8.6.dylib                     0x000000010fca1d0b Tcl_DoOneEvent + 363
# 14  libtk8.6.dylib                      0x000000011020f5fe -[TKApplication(TKInit) applicationDidFinishLaunching:] + 174
# 15  CoreFoundation                      0x00007ff80eb016d6 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 16  CoreFoundation                      0x00007ff80eb9acbc ___CFXRegistrationPost_block_invoke + 86
# 17  CoreFoundation                      0x00007ff80eb9ac13 _CFXRegistrationPost + 534
# 18  CoreFoundation                      0x00007ff80ead4e31 _CFXNotificationPost + 809
# 19  Foundation                          0x00007ff80f849f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 20  AppKit                              0x00007ff811b98c74 -[NSApplication _postDidFinishNotification] + 305
# 21  AppKit                              0x00007ff811b989c6 -[NSApplication _sendFinishLaunchingNotification] + 208
# 22  AppKit                              0x00007ff811b966f2 -[NSApplication(NSAppleEventHandling) _handleAEOpenEvent:] + 541
# 23  AppKit                              0x00007ff811b96348 -[NSApplication(NSAppleEventHandling) _handleCoreEvent:withReplyEvent:] + 665
# 24  Foundation                          0x00007ff80f874d24 -[NSAppleEventManager dispatchRawAppleEvent:withRawReply:handlerRefCon:] + 308
# 25  Foundation                          0x00007ff80f874b96 _NSAppleEventManagerGenericHandler + 80
# 26  AE                                  0x00007ff815010d9d _AppleEventsCheckInAppWithBlock + 14011
# 27  AE                                  0x00007ff815010608 _AppleEventsCheckInAppWithBlock + 12070
# 28  AE                                  0x00007ff815009c1d aeProcessAppleEvent + 419
# 29  HIToolbox                           0x00007ff8189a4e3f AEProcessAppleEvent + 54
# 30  AppKit                              0x00007ff811b91270 _DPSNextEvent + 1738
# 31  AppKit                              0x00007ff811b8fdb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 32  libtk8.6.dylib                      0x0000000110218dbe TkMacOSXEventsSetupProc + 190
# 33  libtcl8.6.dylib                     0x000000010fca1cba Tcl_DoOneEvent + 282
# 34  libtk8.6.dylib                      0x000000011020fc06 TkpInit + 390
# 35  libtk8.6.dylib                      0x0000000110165740 Initialize + 2704
# 36  _tkinter.cpython-39-darwin.so       0x000000010f2ab64b Tcl_AppInit + 91
# 37  _tkinter.cpython-39-darwin.so       0x000000010f2ab339 Tkapp_New + 585
# 38  _tkinter.cpython-39-darwin.so       0x000000010f2ab0de _tkinter_create_impl + 222
# 39  _tkinter.cpython-39-darwin.so       0x000000010f2aabe6 _tkinter_create + 182
# 40  python3.9                           0x000000010500c755 cfunction_vectorcall_FASTCALL + 85
# 41  python3.9                           0x00000001050dde5e call_function + 174
# 42  python3.9                           0x00000001050d6c51 _PyEval_EvalFrameDefault + 27521
# 43  python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 44  python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 45  python3.9                           0x0000000104fb011d _PyObject_FastCallDictTstate + 109
# 46  python3.9                           0x0000000105036750 slot_tp_init + 192
# 47  python3.9                           0x0000000105041700 type_call + 272
# 48  python3.9                           0x0000000104fafe86 _PyObject_MakeTpCall + 134
# 49  python3.9                           0x00000001050ddee7 call_function + 311
# 50  python3.9                           0x00000001050d5f3d _PyEval_EvalFrameDefault + 24173
# 51  python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 52  python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 53  python3.9                           0x00000001050dde5e call_function + 174
# 54  python3.9                           0x00000001050d5f3d _PyEval_EvalFrameDefault + 24173
# 55  python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 56  python3.9                           0x00000001050c8f09 builtin_exec + 377
# 57  python3.9                           0x000000010500c755 cfunction_vectorcall_FASTCALL + 85
# 58  python3.9                           0x00000001050dde5e call_function + 174
# 59  python3.9                           0x00000001050d5f3d _PyEval_EvalFrameDefault + 24173
# 60  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 61  python3.9                           0x00000001050d8013 _PyEval_EvalFrameDefault + 32579
# 62  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 63  python3.9                           0x00000001050d8013 _PyEval_EvalFrameDefault + 32579
# 64  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 65  python3.9                           0x0000000104fbe967 method_vectorcall_O + 103
# 66  python3.9                           0x00000001050dde5e call_function + 174
# 67  python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 68  python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 69  python3.9                           0x00000001050dde5e call_function + 174
# 70  python3.9                           0x00000001050d5f3d _PyEval_EvalFrameDefault + 24173
# 71  python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 72  python3.9                           0x00000001050dde5e call_function + 174
# 73  python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 74  python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 75  python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 76  python3.9                           0x0000000104fb3e2e method_vectorcall + 158
# 77  python3.9                           0x0000000104fb0783 PyVectorcall_Call + 163
# 78  python3.9                           0x00000001050d57d6 _PyEval_EvalFrameDefault + 22278
# 79  python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 80  python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 81  python3.9                           0x0000000104fb3e2e method_vectorcall + 158
# 82  python3.9                           0x00000001050dde5e call_function + 174
# 83  python3.9                           0x00000001050d1252 _PyEval_EvalFrameDefault + 4482
# 84  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 85  python3.9                           0x00000001050d8013 _PyEval_EvalFrameDefault + 32579
# 86  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 87  python3.9                           0x00000001050d8013 _PyEval_EvalFrameDefault + 32579
# 88  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 89  python3.9                           0x00000001050d8013 _PyEval_EvalFrameDefault + 32579
# 90  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 91  python3.9                           0x00000001050d8013 _PyEval_EvalFrameDefault + 32579
# 92  python3.9                           0x0000000104fc9ccf gen_send_ex + 175
# 93  _asyncio.cpython-39-darwin.so       0x000000010e7e897a task_step_impl + 442
# 94  _asyncio.cpython-39-darwin.so       0x000000010e7e872e task_step + 62
# 95  _asyncio.cpython-39-darwin.so       0x000000010e7e85c8 task_wakeup + 104
# 96  _asyncio.cpython-39-darwin.so       0x000000010e7e84bd TaskWakeupMethWrapper_call + 109
# 97  python3.9                           0x0000000104fafe86 _PyObject_MakeTpCall + 134
# 98  python3.9                           0x00000001050f9641 context_run + 81
# 99  python3.9                           0x000000010500c68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 100 python3.9                           0x00000001050d57d6 _PyEval_EvalFrameDefault + 22278
# 101 python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 102 python3.9                           0x00000001050dde5e call_function + 174
# 103 python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 104 python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 105 python3.9                           0x00000001050dde5e call_function + 174
# 106 python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 107 python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 108 python3.9                           0x00000001050dde5e call_function + 174
# 109 python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 110 python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 111 python3.9                           0x00000001050dde5e call_function + 174
# 112 python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 113 python3.9                           0x0000000104fb0bcb function_code_fastcall + 139
# 114 python3.9                           0x00000001050dde5e call_function + 174
# 115 python3.9                           0x00000001050d58fa _PyEval_EvalFrameDefault + 22570
# 116 python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 117 python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 118 python3.9                           0x0000000104fb3e2e method_vectorcall + 158
# 119 python3.9                           0x00000001050dde5e call_function + 174
# 120 python3.9                           0x00000001050d6c51 _PyEval_EvalFrameDefault + 27521
# 121 python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 122 python3.9                           0x00000001050c8f09 builtin_exec + 377
# 123 python3.9                           0x000000010500c755 cfunction_vectorcall_FASTCALL + 85
# 124 python3.9                           0x00000001050dde5e call_function + 174
# 125 python3.9                           0x00000001050d5f3d _PyEval_EvalFrameDefault + 24173
# 126 python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 127 python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 128 python3.9                           0x00000001050dde5e call_function + 174
# 129 python3.9                           0x00000001050d5f3d _PyEval_EvalFrameDefault + 24173
# 130 python3.9                           0x00000001050cea09 _PyEval_EvalCode + 489
# 131 python3.9                           0x0000000104fb0b0c _PyFunction_Vectorcall + 236
# 132 python3.9                           0x0000000105162142 pymain_run_module + 258
# 133 python3.9                           0x0000000105161a01 pymain_run_python + 241
# 134 python3.9                           0x00000001051618c5 Py_RunMain + 37
# 135 python3.9                           0x0000000105162f90 pymain_main + 64
# 136 python3.9                           0x0000000104f47408 main + 56
# 137 dyld                                0x0000000205411310 start + 2432
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/utkarshsingh/opt/anaconda3/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/var/folders/0g/6ppk2rgd6n32_dcc_1d5kpm80000gn/T/ipykernel_90214/180065255.py", line 34, in decrypt
#     alphaValue.grid(row=4,column=1)
# AttributeError: 'NoneType' object has no attribute 'grid'
